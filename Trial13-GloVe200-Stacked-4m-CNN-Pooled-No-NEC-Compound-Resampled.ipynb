# %% [markdown]
# ### Imports & Display Options

# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_columns = 999
pd.options.display.max_rows = 100

# %%
from matplotlib import pylab
import matplotlib.cm as cmap

# %%
import numpy as np
import feather
import re
from datetime import datetime
from itertools import cycle

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc

# %%
from keras.utils import np_utils
from keras.layers import LSTM, Convolution1D, Flatten, Dropout, Dense, GlobalMaxPooling1D, MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.models import Sequential, load_model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import one_hot
from keras.regularizers import l2
from keras.callbacks import TensorBoard, Callback
from keras.metrics import top_k_categorical_accuracy
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Import Data & Clean

# %%
df = pd.read_csv('./BasicCompanyDataAsOneFile-2018-03-01.csv')
df.head()

# %%
def clean_company_name(CompanyName):
    return CompanyName.str.replace('[".,()\-\']', ' ')\
        .str.replace('\s+', ' ').str.strip()\
        .str.replace('LIMITED', 'LTD')\
        .str.replace('INCORPORATED', 'INC')\
        .str.replace('([A-Z])LTD', '\\1 LTD')\
        .str.replace('(LTD|INC|PLC)', '')\
        .str.replace('\\b[A-Z0-9]\\b', '')

def clean(df, label):
    wdf = df[['CompanyName', label]]
    wdf['SICC'] = SICC = wdf[label].str.split(' - ').str[0]
    wdf = wdf[(SICC != '74990') & (SICC != '99999') & (SICC != '7499') & SICC.str.isnumeric()]
    wdf = wdf[wdf.CompanyName.str.count(' ') < 8]
    wdf.dropna(inplace=True)
    return wdf

# %%
df['CompanyName'] = clean_company_name(df.CompanyName)

# %%
len(df)

# %%
wdf = pd.concat([clean(df, 'SICCode.SicText_1'),
                 clean(df, 'SICCode.SicText_2'),
                 clean(df, 'SICCode.SicText_3'),
                 clean(df, 'SICCode.SicText_4')])
len(wdf)

# %%
wdf[wdf.CompanyName.str.contains('!')].sample(20)
# Out:
#                             CompanyName   SICC Industry OrigIndustry
# 3144100                     OH MATRON!   90020      900          900
# 2426640              SO! ENTERTAINMENT   59200      592          592
# 2925092                   YO! SUSHI UK   56101      561          561
# 3188077                       SH!TBOOK   62090     6209          620
# 654720                 CRAIG! RECRUITS   78300      783          783
# 911662      EUREKA! DESIGN CONSULTANTS   73110      731          731
# 2092825                       PREST!GE   47910     4791          479
# 352228                      BIKERIGHT!   85590      855          855
# 2975899                       BAILAME!   90020      900          900
# 3145723                       ONIT! PR   82190      821          821
# 1201459             HELP! MARKETING UK   47910     4791          479
# 2910599                         WUUF !   62011     6201          620
# 2671153                THINK! FLOORING   43330      433          433
# 3359723     WIN! WIRELESS INTELLIGENCE   62090     6209          620
# 3309031               LET THE GEEK OUT!  90030      900          900
# 2451101  SPARK! INTERNATIONAL HOLDINGS   74100      741          741
# 2335424                      SCRUB UP!   47750      477          477
# 1210452                     HEYBIGMAN!   62090     6209          620
# 1926709               OH! CHOCOLATE UK   96040     9604          960
# 445471                BURN! MOTORSPORT   47910     4791          479

# %% [markdown]
# ### Remove Unknown Names

# %%
wdf['WordSum'] = wdf.CompanyName.apply(words_below_rank(35000))
(wdf.WordSum == 0).sum()
# Out:
# 204632

# %%
# Remove super short names
(wdf.CompanyName.str.len() < 6).sum()
# Out:
# 15406

# %%
wdf.sample(50)
# Out:
#                                            CompanyName   SICC  \
# 254144                              APEXIA CONSULTING   82990
# 3339699                           THE PLAYWRITE GROUP   46900
# 4147519                                   KINDLEGRADE   68320
# 1192704                           FANCHY DESIGN GROUP   74100
# 466668                                         BLH UK   84230
# 2685516                                    PUPILASSET   63110
# 2046189                               LUMSDEN SUPPORT   82990
# 948693                                 DESIGNA BLINDS   47190
# 2632615                      PRAISE MANPOWER SERVICES   86101
# 1225059                                    FIRE MEDIA   60100
# 3828659                                     EVENDITIO   47910
# 2548330                              PENGUIN CHEM ENG   71121
# 3220948                 DOMAIN ELECTRICAL CONTRACTORS   43210
# 2427158                                 OCTAVIA LEEDS   56101
# 269024                                       ARCHDESI   74100
# 3793950           CORONA ASSET RECOVERY INTERNATIONAL   82911
# 690153                           CHESHIRE REAL ESTATE   68100
# 2611155                    PNW ARCHITECTURAL SERVICES   71111
# 2838057                            ROCKET HOSPITALITY   82990
# 2125611                                    MARKGODSON   96090
# 3812725                                DOUBLE RHOMBUS   63990
# 4059451                            UNIVERSAL CREATIVE   74201
# 2024904   LONGFORD ELECTRICAL AND MECHANICAL SERVICES   33190
# 2205596                                 MICHAEL MILES   60200
# 685524                     CHELLASTON DENTAL PRACTICE   86230
# 4170000                                   PARK HEALTH   86900
# 2992227                                       SHENAIL   82990
# 2086920                                   MAGIC TRANS   49410
# 2091590                      MAINE MICROWAVE SERVICES   33140
# 3934746                               MJL CONTRACTORS   43120
# 1761834                               JJC ENGINEERING   25990
# 2105340                                 MANIA TRADING   47990
# 17782                21 24 WESTBURY COURT RTM COMPANY   98000
# 4186176                             SHEPPARD & BARROW   68209
# 3110183                               SPOT PROMOTIONS   46900
# 2368796                              NICOLE TRANSPORT   82990
# 4200638                      TONY & BELL DEVELOPMENTS   41202
# 2950365                               SDG INVESTMENTS   66300
# 1465513                         HALLGARTH MANOR HOTEL   55100
# 3211576                             SWROSS CONSULTING   96090
# 1762637                        JJS AND SONS SOLUTIONS   82990
# 1753337                                          JESW   86101
# 3128713                                        STACRA   28990
# 607986   CANARY VIEW NARROW STREET MANAGEMENT COMPANY   98000
# 2250096                                        MODECO   41202
# 11617                     18 BEAUFORT ROAD MANAGEMENT   98000
# 378417                        BARNES PLATING SERVICES   33110
# 1948425                    LEAKER DIRECT DISTRIBUTION   46900
# 4015975                       SN SOLUTIONS CONSULTANT   06200
# 3578830                      WATER II WINE MINISTRIES   85590
#
#                                          SICCode.SicText_1  \
# 254144   82990 - Other business support service activit...
# 3339699            46900 - Non-specialised wholesale trade
# 4147519                                               None
# 1192704              74100 - specialised design activities
# 466668             84230 - Justice and judicial activities
# 2685516  63110 - Data processing, hosting and related a...
# 2046189  82990 - Other business support service activit...
# 948693   47190 - Other retail sale in non-specialised s...
# 2632615                        86101 - Hospital activities
# 1225059                         60100 - Radio broadcasting
# 3828659                                               None
# 2548330  71121 - Engineering design activities for indu...
# 3220948                    43210 - Electrical installation
# 2427158                       56101 - Licensed restaurants
# 269024               74100 - specialised design activities
# 3793950                                               None
# 690153       68100 - Buying and selling of own real estate
# 2611155                   71111 - Architectural activities
# 2838057  82990 - Other business support service activit...
# 2125611            96090 - Other service activities n.e.c.
# 3812725                                               None
# 4059451                                               None
# 2024904                  33190 - Repair of other equipment
# 2205596  60200 - Television programming and broadcastin...
# 685524                  86230 - Dental practice activities
# 4170000                                               None
# 2992227  82990 - Other business support service activit...
# 2086920                  49410 - Freight transport by road
# 2091590             33140 - Repair of electrical equipment
# 3934746                                               None
# 1761834  25990 - Manufacture of other fabricated metal ...
# 2105340  47990 - Other retail sale not in stores, stall...
# 17782                98000 - Residents property management
# 4186176                                               None
# 3110183            46900 - Non-specialised wholesale trade
# 2368796  82990 - Other business support service activit...
# 4200638                                               None
# 2950365                 66300 - Fund management activities
# 1465513           55100 - Hotels and similar accommodation
# 3211576            96090 - Other service activities n.e.c.
# 1762637  82990 - Other business support service activit...
# 1753337                        86101 - Hospital activities
# 3128713  28990 - Manufacture of other special-purpose m...
# 607986               98000 - Residents property management
# 2250096         41202 - Construction of domestic buildings
# 11617                98000 - Residents property management
# 378417         33110 - Repair of fabricated metal products
# 1948425            46900 - Non-specialised wholesale trade
# 4015975                                               None
# 3578830                     85590 - Other education n.e.c.
#
#                                          SICCode.SicText_2  \
# 254144                                                None
# 3339699                                               None
# 4147519                                               None
# 1192704                                               None
# 466668                                                None
# 2685516                                               None
# 2046189                                               None
# 948693                                                None
# 2632615                                               None
# 1225059                                               None
# 3828659  47910 - Retail sale via mail order houses or v...
# 2548330                                               None
# 3220948                                               None
# 2427158                                               None
# 269024                                                None
# 3793950          82911 - Activities of collection agencies
# 690153                                                None
# 2611155                                               None
# 2838057                                               None
# 2125611                                               None
# 3812725  63990 - Other information service activities n...
# 4059451           74201 - Portrait photographic activities
# 2024904                                               None
# 2205596                                               None
# 685524                                                None
# 4170000                                               None
# 2992227                                               None
# 2086920                                               None
# 2091590                                               None
# 3934746                           43120 - Site preparation
# 1761834                                               None
# 2105340                                               None
# 17782                                                 None
# 4186176                                               None
# 3110183                                               None
# 2368796                                               None
# 4200638                                               None
# 2950365                                               None
# 1465513                                               None
# 3211576                                               None
# 1762637                                               None
# 1753337                                               None
# 3128713                                               None
# 607986                                                None
# 2250096                                               None
# 11617                                                 None
# 378417                                                None
# 1948425                                               None
# 4015975                  06200 - Extraction of natural gas
# 3578830                                               None
#
#                                          SICCode.SicText_3 SICCode.SicText_4  \
# 254144                                                None              None
# 3339699                                               None              None
# 4147519  68320 - Management of real estate on a fee or ...              None
# 1192704                                               None              None
# 466668                                                None              None
# 2685516                                               None              None
# 2046189                                               None              None
# 948693                                                None              None
# 2632615                                               None              None
# 1225059                                               None              None
# 3828659                                               None              None
# 2548330                                               None              None
# 3220948                                               None              None
# 2427158                                               None              None
# 269024                                                None              None
# 3793950                                               None              None
# 690153                                                None              None
# 2611155                                               None              None
# 2838057                                               None              None
# 2125611                                               None              None
# 3812725                                               None              None
# 4059451                                               None              None
# 2024904                                               None              None
# 2205596                                               None              None
# 685524                                                None              None
# 4170000              86900 - Other human health activities              None
# 2992227                                               None              None
# 2086920                                               None              None
# 2091590                                               None              None
# 3934746                                               None              None
# 1761834                                               None              None
# 2105340                                               None              None
# 17782                                                 None              None
# 4186176  68209 - Other letting and operating of own or ...              None
# 3110183                                               None              None
# 2368796                                               None              None
# 4200638         41202 - Construction of domestic buildings              None
# 2950365                                               None              None
# 1465513                                               None              None
# 3211576                                               None              None
# 1762637                                               None              None
# 1753337                                               None              None
# 3128713                                               None              None
# 607986                                                None              None
# 2250096                                               None              None
# 11617                                                 None              None
# 378417                                                None              None
# 1948425                                               None              None
# 4015975                                               None              None
# 3578830                                               None              None
#
#          WordSum
# 254144         3
# 3339699        3
# 4147519        2
# 1192704        3
# 466668         1
# 2685516        2
# 2046189        1
# 948693         1
# 2632615        3
# 1225059        2
# 3828659        1
# 2548330        2
# 3220948        3
# 2427158        1
# 269024         1
# 3793950        4
# 690153         3
# 2611155        2
# 2838057        2
# 2125611        1
# 3812725        1
# 4059451        2
# 2024904        4
# 2205596        2
# 685524         2
# 4170000        2
# 2992227        2
# 2086920        2
# 2091590        3
# 3934746        1
# 1761834        1
# 2105340        2
# 17782          4
# 4186176        2
# 3110183        2
# 2368796        2
# 4200638        3
# 2950365        1
# 1465513        4
# 3211576        3
# 1762637        3
# 1753337        0
# 3128713        1
# 607986         6
# 2250096        2
# 11617          4
# 378417         2
# 1948425        2
# 4015975        3
# 3578830        4

# %%
custom_tokenize2('musicality')
# Out:
# [74699]

# %%
wdf[wdf.WordSum == 0].sample(50)
# Out:
#                       CompanyName   SICC  \
# 3026722                   SIRASA   47300
# 1456167          CHEMIE PELZER     29320
# 4078392                     XOYA   62012
# 701339               CHORLEY RVN   75000
# 3698295                   YUSHAN   62090
# 2432254                OHANA AYH   70229
# 4090424                  ANIMESH   74100
# 2252290                     MOGI   68209
# 3321883          THE L8 BLOOMERS   63910
# 653579                   CEDARS    98000
# 3469359              1F364  2604   82990
# 3685574                   YEOMEN   82990
# 1872743    KINGSWOOD RADIOGRAPHY   86900
# 593                         01BS   82990
# 1155008                 EUROTECH   26512
# 4252366                   RENARD   85590
# 3768919                   BROXAP   25110
# 3788601         COCKBURN  SHOPPE   47290
# 388836              BAWDEN GEARY   82990
# 829773            CRE8TIVE KUDOS   62090
# 43498                        5KC   41201
# 1329839                  GAUDINS   74909
# 3399796                   TOKARA   70229
# 3483186          UMMAH JEWELLERS   32120
# 4031106                    SYORA   86210
# 3829396                   EWEMIK   52219
# 3226765                   NASEBY   41202
# 3671937                WYNCLIFFE   28490
# 2378936         NMP FABRICATIONS   24200
# 438031                  BIBLOTEK   62012
# 1814036                    MUSIQ   82990
# 1716447                      J2L   62090
# 768152           COLSTON GLAZING   43390
# 4155207                     MAKU   90030
# 3996748               ROZENBROEK   14141
# 2201220                     MGX2   68209
# 1308280                   WISTOW   70229
# 95539    ABINGDON REFURBISHMENTS   41202
# 74569                       POPA   82990
# 3381500                     TIGA   35220
# 577735                    RUDDLE   70221
# 1693646                    IZAAK   31090
# 2778566                 REGICIDE   41202
# 3470637                   UBIETY   47910
# 3528289                  VESALUX   46900
# 2300678               MUSICALITY   96090
# 1896074                     KRIC   70229
# 3932069                  MIDGARD   41202
# 770664                    COMITA   62020
# 3389305                    TIOTE   69202
#
#                                          SICCode.SicText_1  \
# 3026722  47300 - Retail sale of automotive fuel in spec...
# 1456167  29320 - Manufacture of other parts and accesso...
# 4078392                                               None
# 701339                       75000 - Veterinary activities
# 3698295  62090 - Other information technology service a...
# 2432254  70229 - Management consultancy activities othe...
# 4090424                                               None
# 2252290  68209 - Other letting and operating of own or ...
# 3321883                     63910 - News agency activities
# 653579               98000 - Residents property management
# 3469359  82990 - Other business support service activit...
# 3685574  82990 - Other business support service activit...
# 1872743              86900 - Other human health activities
# 593      82990 - Other business support service activit...
# 1155008  26512 - Manufacture of electronic industrial p...
# 4252366                                               None
# 3768919                                               None
# 3788601                                               None
# 388836   82990 - Other business support service activit...
# 829773   62090 - Other information technology service a...
# 43498         41201 - Construction of commercial buildings
# 1329839  74909 - Other professional, scientific and tec...
# 3399796  70229 - Management consultancy activities othe...
# 3483186  32120 - Manufacture of jewellery and related a...
# 4031106                                               None
# 3829396                                               None
# 3226765         41202 - Construction of domestic buildings
# 3671937         28490 - Manufacture of other machine tools
# 2378936  24200 - Manufacture of tubes, pipes, hollow pr...
# 438031   62012 - Business and domestic software develop...
# 1814036  82990 - Other business support service activit...
# 1716447  62090 - Other information technology service a...
# 768152     43390 - Other building completion and finishing
# 4155207                                               None
# 3996748                                               None
# 2201220  68209 - Other letting and operating of own or ...
# 1308280  70229 - Management consultancy activities othe...
# 95539           41202 - Construction of domestic buildings
# 74569    82990 - Other business support service activit...
# 3381500  35220 - Distribution of gaseous fuels through ...
# 577735                        70221 - Financial management
# 1693646             31090 - Manufacture of other furniture
# 2778566         41202 - Construction of domestic buildings
# 3470637  47910 - Retail sale via mail order houses or v...
# 3528289            46900 - Non-specialised wholesale trade
# 2300678            96090 - Other service activities n.e.c.
# 1896074  70229 - Management consultancy activities othe...
# 3932069                                               None
# 770664   62020 - Information technology consultancy act...
# 3389305                     69202 - Bookkeeping activities
#
#                                          SICCode.SicText_2  \
# 3026722                                               None
# 1456167                                               None
# 4078392  62012 - Business and domestic software develop...
# 701339                                                None
# 3698295                                               None
# 2432254                                               None
# 4090424                                               None
# 2252290                                               None
# 3321883                                               None
# 653579                                                None
# 3469359                                               None
# 3685574                                               None
# 1872743                                               None
# 593                                                   None
# 1155008                                               None
# 4252366                                               None
# 3768919  25110 - Manufacture of metal structures and pa...
# 3788601  47290 - Other retail sale of food in specialis...
# 388836                                                None
# 829773                                                None
# 43498                                                 None
# 1329839                                               None
# 3399796                                               None
# 3483186                                               None
# 4031106        86210 - General medical practice activities
# 3829396  52219 - Other service activities incidental to...
# 3226765                                               None
# 3671937                                               None
# 2378936                                               None
# 438031                                                None
# 1814036                                               None
# 1716447                                               None
# 768152                                                None
# 4155207                                               None
# 3996748             14141 - Manufacture of men's underwear
# 2201220                                               None
# 1308280                                               None
# 95539                                                 None
# 74569                                                 None
# 3381500                                               None
# 577735                                                None
# 1693646                                               None
# 2778566                                               None
# 3470637                                               None
# 3528289                                               None
# 2300678                                               None
# 1896074                                               None
# 3932069         41202 - Construction of domestic buildings
# 770664                                                None
# 3389305                                               None
#
#                              SICCode.SicText_3  \
# 3026722                                   None
# 1456167                                   None
# 4078392                                   None
# 701339                                    None
# 3698295                                   None
# 2432254                                   None
# 4090424  74100 - specialised design activities
# 2252290                                   None
# 3321883                                   None
# 653579                                    None
# 3469359                                   None
# 3685574                                   None
# 1872743                                   None
# 593                                       None
# 1155008                                   None
# 4252366                                   None
# 3768919                                   None
# 3788601                                   None
# 388836                                    None
# 829773                                    None
# 43498                                     None
# 1329839                                   None
# 3399796                                   None
# 3483186                                   None
# 4031106                                   None
# 3829396                                   None
# 3226765                                   None
# 3671937                                   None
# 2378936                                   None
# 438031                                    None
# 1814036                                   None
# 1716447                                   None
# 768152                                    None
# 4155207              90030 - Artistic creation
# 3996748                                   None
# 2201220                                   None
# 1308280                                   None
# 95539                                     None
# 74569                                     None
# 3381500                                   None
# 577735                                    None
# 1693646                                   None
# 2778566                                   None
# 3470637                                   None
# 3528289                                   None
# 2300678                                   None
# 1896074                                   None
# 3932069                                   None
# 770664                                    None
# 3389305                                   None
#
#                       SICCode.SicText_4  WordSum
# 3026722                            None        0
# 1456167                            None        0
# 4078392                            None        0
# 701339                             None        0
# 3698295                            None        0
# 2432254                            None        0
# 4090424                            None        0
# 2252290                            None        0
# 3321883                            None        0
# 653579                             None        0
# 3469359                            None        0
# 3685574                            None        0
# 1872743                            None        0
# 593                                None        0
# 1155008                            None        0
# 4252366  85590 - Other education n.e.c.        0
# 3768919                            None        0
# 3788601                            None        0
# 388836                             None        0
# 829773                             None        0
# 43498                              None        0
# 1329839                            None        0
# 3399796                            None        0
# 3483186                            None        0
# 4031106                            None        0
# 3829396                            None        0
# 3226765                            None        0
# 3671937                            None        0
# 2378936                            None        0
# 438031                             None        0
# 1814036                            None        0
# 1716447                            None        0
# 768152                             None        0
# 4155207                            None        0
# 3996748                            None        0
# 2201220                            None        0
# 1308280                            None        0
# 95539                              None        0
# 74569                              None        0
# 3381500                            None        0
# 577735                             None        0
# 1693646                            None        0
# 2778566                            None        0
# 3470637                            None        0
# 3528289                            None        0
# 2300678                            None        0
# 1896074                            None        0
# 3932069                            None        0
# 770664                             None        0
# 3389305                            None        0

# %%
wdf = wdf[(wdf.WordSum > 0) & (wdf.CompanyName.str.len() > 6) & (wdf.SICC.str.len() == 5)]
len(wdf)

# %%
# Remove company names that are all numbers
wdf = wdf[~wdf.CompanyName.str.match('^[0-9\\s]+$')]
len(wdf)

# %% [markdown]
# ### Feature Engineering

# %%
custom_tokenize2('obac uk')
# Out:
# [34539, 6549, 2046]

# %%
hard_to_classify_set = {"829", "479", "960", "329", "639", "289", "661", "702"}
grouped_classify_set = {"01", "02", "03", "09", "10", "13", "22", "23", "38", "46", "50", "78", "79", "80"}
def merge_split_classes(value):
    if value[:2] in grouped_classify_set:
        return value[:2]
    elif value[:3] in hard_to_classify_set:
        return value[:4]
    else:
        return value[:3]

# %%
# Split some hard to classify classes out
wdf['Industry'] = wdf.SICC.apply(merge_split_classes)
# Out:
# /Users/zeb.zhao/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# These class is not possible to predict, a bunch of misc.
wdf = wdf[wdf.Industry != '8299']  # Other business activities (n.e.c)
print(len(wdf))
wdf = wdf[wdf.Industry != '9609']  # Other service activities (n.e.c)
print(len(wdf))
wdf = wdf[wdf.Industry != '4618']  # Sales of other products
print(len(wdf))
wdf = wdf[wdf.Industry != '4619']  # Sales of variety of goods
print(len(wdf))
wdf = wdf[wdf.Industry != '559']  # Other accomodations
print(len(wdf))
wdf = wdf[wdf.Industry != '332']  # Industrial machinery
print(len(wdf))
wdf = wdf[wdf.Industry != '682']  # Renting and leasing real estate
print(len(wdf))
wdf = wdf[wdf.SICC != '74909']   # Other professional, scientific, technical activities (n.e.c)
print(len(wdf))
wdf = wdf[wdf.SICC != '79909']   # Other reservation service activities (n.e.c)
print(len(wdf))
wdf = wdf[wdf.SICC != '63990']   # Other infomation service activities (n.e.c)
print(len(wdf))
wdf = wdf[wdf.SICC != '47990']   # Other retail sales
print(len(wdf))
wdf = wdf[wdf.SICC != '68209']   # Other letting operating real estate (n.e.c)
print(len(wdf))
wdf = wdf[wdf.SICC != '66190']   # Activities auxiliary financial intermediation (n.e.c)
print(len(wdf))
# Out:
# 3766230
# 3628296
# 3621491
# 3613690
# 3603217
# 3597829
# 3454743
# 3374256
# 3370077
# 3343987
# 3316492
# 3316492
# 3307877

# %%
wdf[wdf.CompanyName.str.strip(' *&^/\?!@#$%^*()~`|{}-+:;<>,.0123456789').str.len() < 6]
# Out:
#           CompanyName   SICC Industry OrigIndustry
# 0             !NNOV8   62090     6209          620
# 26              COOL   43220      432          432
# 88             & GB    42990      429          429
# 99             RINGS   46900      469          469
# 164            SALON   96020     9602          960
# 170            ZUZIA   49410      494          494
# 171      $$ DEALS $$   47910     4791          479
# 173        $10 CHIMP   70210     7021          702
# 179          & BLANC   47710      477          477
# 184            & NEW   46470     4647          464
# 186           & ROLL   70229     7022          702
# 187           & SIGN   61900      619          619
# 188          & SMITH   90030      900          900
# 195          & TONIC   73110      731          731
# 204           &EARTH   47910     4791          479
# 207            &HYPE   73200      732          732
# 215           &PITCH   59120      591          591
# 216           &RATIO   47599      475          475
# 220            &TAPS   62012     6201          620
# 258             TOUR   56103      561          561
# 270            DRIVE   53202      532          532
# 411            UK WF   70221     7022          702
# 431             SING   46160     4616          461
# 440         001SPORT   93199      931          931
# 453           DODD &   62020     6202          620
# 473            /DEV    62020     6202          620
# 477            DRIFT   46160     4616          461
# 484           TO 100   47910     4791          479
# 493           00 BAR   56101      561          561
# 495         00 NIGEL   70229     7022          702
# 502         001 FUSE   61900      619          619
# 503        001 GROUP   71111      711          711
# 510        006 PUBCO   56302      563          563
# 512         007 CARS   49320      493          493
# 524        007 STEPS   93290      932          932
# 539         01 ADANA   56102      561          561
# 548         01 FILMS   59111      591          591
# 549         01 GROUP   62020     6202          620
# 552            01 IT   62090     6209          620
# 553         01 KOZAN   56103      561          561
# 571        010414 UK   58290      582          582
# 583        0161 CREW   47710      477          477
# 586        0161 MANC   14190      141          141
# 587           017ADV   70229     7022          702
# 589        019 GROUP   70100      701          701
# 597           01TEMP   62020     6202          620
# 599         02 BESNI   56103      561          561
# 605           020LDN   14131      141          141
# 610        0260 CARS   45111      451          451
# 613           027LAB   73110      731          731
# ...               ...    ...      ...          ...
# 4262765         CARE   97000      970          970
# 4262909       VASEA    43310      433          433
# 4263061    VERGE 360   70229     7022          702
# 4263062        VERGE   90030      900          900
# 4263129        VEYDA   68320      683          683
# 4263197        VIDMA   98100      981          981
# 4263213        VIIDA   62020     6202          620
# 4263251        VINOX   68320      683          683
# 4263384        VISLO   72190      721          721
# 4263426        VITAX   28990     2899          289
# 4263440        VIVAA   86900      869          869
# 4263527        VOID5   63110      631          631
# 4263530        VOIST   90030      900          900
# 4263606        VSNRY   47910     4791          479
# 4263656      & TRADE   73120      731          731
# 4263657        & ART   90040      900          900
# 4263678        SPICE   65202      652          652
# 4263681         SNOW   43341      433          433
# 4263719        WAGON   85590      855          855
# 4263722        WAHKR   68320      683          683
# 4263882        WAVE2   62090     6209          620
# 4263916        WCART   90030      900          900
# 4263997       WEB 23   93130      931          931
# 4264152        WEMIX   59132      591          591
# 4264448        WIBDI   78300      783          783
# 4264663        WINOX   90020      900          900
# 4265065        WSACP   45320      453          453
# 4265083        WUPPY   63120      631          631
# 4265090        WWUK1   56290      562          562
# 4265108        WYRED   62090     6209          620
# 4265150        XCITE   82301      823          823
# 4265184        XICON   63110      631          631
# 4265185        XIGUA   93199      931          931
# 4265195        XIST2   63110      631          631
# 4265211        XOONS   73110      731          731
# 4265329     YCS 2010   87300      873          873
# 4265366        YESTV   90040      900          900
# 4265432     YONEV 62   93120      931          931
# 4265630        ZAMAN   56102      561          561
# 4265663        ZE UK   62090     6209          620
# 4265690        ZEETO   74209      742          742
# 4265693        ZELAB   95110      951          951
# 4265727      ZERO 32   63110      631          631
# 4265736     ZEST 365   47910     4791          479
# 4265752       ZETOM1   68320      683          683
# 4265780        ZIFAN   43390      433          433
# 4265781        ZIGIT   70229     7022          702
# 4265856       ZOOM &   52219      522          522
# 4265886        ZUPHO   63120      631          631
# 4265908        ZZASH   68320      683          683
#
# [58711 rows x 4 columns]

# %%
wdf = wdf[wdf.CompanyName.str.strip(' *&^/\?!@#$%^*()~`|{}-+:;<>,.0123456789').str.len() > 5]

# %%
wdf.sample(50)
# Out:
#                                             CompanyName   SICC Industry  \
# 3623977                            WHYTES OF MONIFIETH   43220      432
# 2194222                                     METALDANCE   33190      331
# 434989                                  BGAM HOTELS SH   64209     6420
# 2000814                               LIVINGCITY CO UK   62090     6209
# 1156056                            EVALUCOM CONSULTING   62012     6201
# 2151764                       MAYFIELD SCHOOL SERVICES   47710      477
# 1033574                                 DW PERFORMANCE   45200      452
# 2214180                          MIGHTY GOOD UNDIES UK   14141      141
# 4087673                            AJAY KUMAR ADVOCATE   69109      691
# 820627                                      COX & HALL   43220      432
# 714260                  CITADEL HEALTHCARE SERVICES UK   87200      872
# 2398541                                   NOT JUST IOW   69202      692
# 2746104                               RAVEN ROCK GAMES   62011     6201
# 4225936                               DIGITAL BROTHERS   63110      631
# 623121                                CARES LABORATORY   20120      201
# 1065229                                ECOSSE FAIRWAYS   56101      561
# 379309                 BARNSTILE RESIDENTS ASSOCIATION   98000      980
# 475511                             BLUE SPOT COMPUTERS   47410      474
# 992204                                   DOKIC JOINERY   16230      162
# 2476968                         OVAL PARK CONSTRUCTION   43999      439
# 688783                     CHERRYHILL RESTAURANT GROUP   56101      561
# 2840346                                   RODGER SIGNS   43390      433
# 2301010                                   MUSLIM MEDIA   18130      181
# 2039594                                    LT CLEANING   81210      812
# 1833717                                        KAVANET   18201      182
# 3536822                                    VIKTOR WYND   91020      910
# 2149895                                    MAY STANLEY   62020     6202
# 3104412                           SPILLARD CONSULTANTS   70229     7022
# 3537096                                     VILLA PLUS   79120      791
# 2145503                      MAURA PR & COMMUNICATIONS   58110      581
# 3035829                                      SKG HOMES   68100      681
# 2982419                           SHAKES & BAKES STOKE   56103      561
# 3124088  ST JOHNS COURT STANNINGLEY MANAGEMENT COMPANY   98000      980
# 748286                       CLYDFAN NETWORK SOLUTIONS   62020     6202
# 386763                                      BATH CANDY   20420      204
# 323023                            AUDIOLEASE EQUIPMENT   77291      772
# 4097692                                      BIG GREEN   81100      811
# 4242623                      MARGOT LANG WILLAR DESIGN   74100      741
# 206185                                   ALTUN FINANCE   64999      649
# 2047918                            LUTESTAR SIMULATION   62090     6209
# 690766                                CHESTER BOOTCAMP   93199      931
# 2155789                                   MBP PROJECTS   70229     7022
# 3112937                              SPRINGS SMOKERIES   10200      102
# 1291763                              FULCRUM NORTH SEA   71122      711
# 1645318                      INGLETON WOOD MARTINDALES   71111      711
# 3668212                            WRITING ROOM LONDON   73120      731
# 852178                                      CSP II CRC   66300      663
# 312905                             AT FIT OUT GROUP UK   41201      412
# 4199926                                      TIGERLIME   68320      683
# 4108614                                   COLOUROFFICE   74209      742
#
#         OrigIndustry
# 3623977          432
# 2194222          331
# 434989           642
# 2000814          620
# 1156056          620
# 2151764          477
# 1033574          452
# 2214180          141
# 4087673          691
# 820627           432
# 714260           872
# 2398541          692
# 2746104          620
# 4225936          631
# 623121           201
# 1065229          561
# 379309           980
# 475511           474
# 992204           162
# 2476968          439
# 688783           561
# 2840346          433
# 2301010          181
# 2039594          812
# 1833717          182
# 3536822          910
# 2149895          620
# 3104412          702
# 3537096          791
# 2145503          581
# 3035829          681
# 2982419          561
# 3124088          980
# 748286           620
# 386763           204
# 323023           772
# 4097692          811
# 4242623          741
# 206185           649
# 2047918          620
# 690766           931
# 2155789          702
# 3112937          102
# 1291763          711
# 1645318          711
# 3668212          731
# 852178           663
# 312905           412
# 4199926          683
# 4108614          742

# %%
custom_tokenize2('VIKTOR')
# Out:
# [7510]

# %% [markdown]
# ### Check for Class Imbalance

# %%
def plot_frequency(df, feature, top=50):
    classes = df.groupby([feature]).CompanyName.count().sort_values(ascending=False)
    print('AVG: ', classes.mean())
    return classes.head(top).plot(kind='bar', figsize=(10, 3))

# %%
plot_frequency(wdf, 'Industry')
# Out:
# AVG:  10779.2

# %%
plot_frequency(wdf, 'SICC')
# Out:
# AVG:  4522.741258741259

# %%
min_class_count = 1000
classes = wdf.groupby(['Industry']).count().sort_values('CompanyName', ascending=False)
print(' Classes below %s samples: %s/%s' % (min_class_count, (classes.CompanyName < min_class_count).sum(), len(classes.CompanyName)))
# Out:
#  Classes below 1000 samples: 86/300

# %%
classes[classes.CompanyName < min_class_count].head()
# Out:
#           CompanyName  SICC  OrigIndustry
# Industry
# 982               994   994           994
# 6391              977   977           977
# 613               976   976           976
# 324               965   965           965
# 501               964   964           964

# %%
classes[classes.CompanyName < min_class_count].sum()
# Out:
# CompanyName     36186
# SICC            36186
# OrigIndustry    36186
# dtype: int64

# %%
# Remove classes with low count
to_replace = classes[classes.CompanyName < min_class_count].index
wdf['Industry'] = wdf['Industry'].replace(to_replace, '0')
# Remove unknown data
wdf = wdf[wdf['Industry'] != '0']
len(wdf)
# Out:
# 3161165

# %% [markdown]
# ### Resample Data

# %%
plot_frequency(wdf, 'Industry')
# Out:
# AVG:  10779.2

# %%
plot_frequency(wdf, 'SICC')
# Out:
# AVG:  4522.741258741259

# %%
def resample_classes(df, groupby, samples):
    classes = wdf.groupby([groupby]).CompanyName.count()
    freqs = dict(samples/classes)
    freq = df[groupby].map(freqs)
    np.random.seed(42)
    criteria = np.random.rand(len(df)) < freq
    return df[criteria]

# %%
rwdf = resample_classes(wdf, 'Industry', 6000)

# %%
plot_frequency(rwdf, 'Industry')
# Out:
# AVG:  3124.5866666666666

# %%
plot_frequency(rwdf, 'SICC')
# Out:
# AVG:  1311.0153846153846

# %% [markdown]
# ### Pickle Working Set

# %%
feather.write_dataframedata(df, 'df.feather')

# %%
feather.write_dataframe(wdf, 'wdf4ms.feather')  # SIC Text 1, 2, 3, 4 stacked

# %%
feather.write_dataframe(wdf, 'wdf4msk.feather')  # Unknown names removed

# %%
feather.write_dataframe(wdf, 'wdf4mskf.feather')  # Feature engineered

# %%
feather.write_dataframe(wdf, 'wdf4mskfr.feather')  # Resampled classes

# %%
wdf = feather.read_dataframe('wdf4mskfr.feather')
wdf.head()
# Out:
#         CompanyName   SICC                                  SICCode.SicText_1  \
# 0           !NNOV8   62090  62090 - Other information technology service a...
# 1         !NSPIRED   70229  70229 - Management consultancy activities othe...
# 2  !NVERTD DESIGNS   58190                58190 - Other publishing activities
# 3         !OBAC UK   70229  70229 - Management consultancy activities othe...
# 4       !YOZO FASS   90010                            90010 - Performing arts
#
#   SICCode.SicText_2 SICCode.SicText_3 SICCode.SicText_4  WordSum
# 0              None              None              None    22147
# 1              None              None              None      639
# 2              None              None              None    15637
# 3              None              None              None    43134
# 4              None              None              None   349123

# %% [markdown]
# ### Label Encoding

# %%
industry_encoder = LabelEncoder()
industry_encoder.fit(rwdf['Industry'])
encoded_industry = industry_encoder.transform(rwdf['Industry'])
industry_labels = np_utils.to_categorical(encoded_industry)
industry_labels.shape
# Out:
# (937376, 300)

# %%
num_industries = industry_labels.shape[1]

# %% [markdown]
# ### Text Encoding

# %%
def load_glove_embeddings(fp, embedding_dim, include_empty_char=True):
    """
    Loads pre-trained word embeddings (GloVe embeddings)
        Inputs: - fp: filepath of pre-trained glove embeddings
                - embedding_dim: dimension of each vector embedding
                - generate_matrix: whether to generate an embedding matrix
        Outputs:
                - word2coefs: Dictionary. Word to its corresponding coefficients
                - word2index: Dictionary. Word to word-index
                - embedding_matrix: Embedding matrix for Keras Embedding layer
    """
    # First, build the "word2coefs" and "word2index"
    word2coefs = {} # word to its corresponding coefficients
    word2index = {} # word to word-index
    with open(fp) as f:
        for idx, line in enumerate(f):
            try:
                data = [x.strip().lower() for x in line.split()]
                word = data[0]
                coefs = np.asarray(data[1:embedding_dim+1], dtype='float32')
                word2coefs[word] = coefs
                if word not in word2index:
                    word2index[word] = len(word2index)
            except Exception as e:
                print('Exception occurred in `load_glove_embeddings`:', e)
                continue
        # End of for loop.
    # End of with open
    if include_empty_char:
        word2index[''] = len(word2index)
    # Second, build the "embedding_matrix"
    # Words not found in embedding index will be all-zeros. Hence, the "+1".
    vocab_size = len(word2coefs)+1 if include_empty_char else len(word2coefs)
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, idx in word2index.items():
        embedding_vec = word2coefs.get(word)
        if embedding_vec is not None and embedding_vec.shape[0]==embedding_dim:
            embedding_matrix[idx] = np.asarray(embedding_vec)
    # return word2coefs, word2index, embedding_matrix
    return word2index, np.asarray(embedding_matrix)

# %%
word2index, embedding_matrix = load_glove_embeddings('glove.6B/glove.6B.200d.txt', embedding_dim=200)

# %%
def custom_tokenize(d):
    return [word2index.get(re.sub(r'[^\w\s]','',w).lower(), 0) for w in d.split()]

# %%
def custom_tokenize2(d):
    tokens = []
    words = d.split()
    for word in words:
        word = re.sub(r'[^\w\s]','',word).lower()
        if word in word2index:
            tokens.append(word2index[word])
        else:
            for w in split_compound_words(word, word2index):
                if len(w) == 1:
                    tokens.append(0)
                else:
                    tokens.append(word2index.get(w, 0))
    return tokens

def split_compound_words(word, corpus):
    result = [word]
    word = word.strip('0123456789!?,. ')
    min_score = 2e5
    max_threshold = 3e4
    min_threshold = 250
    for x in range(1, len(word)+1):
        head, tail = word[:x], word[x:]
        head_score = corpus.get(head, 2e5/2) + max(0, -len(head)*20000 + 60000)
        tail_score = corpus.get(tail, 2e5/2) + max(0, -len(tail)*20000 + 60000)
        if ((min_threshold < head_score < max_threshold) or
            (min_threshold < tail_score < max_threshold)):
            if (head_score + tail_score) < min_score:
                result = [head, tail]
                min_score = head_score + tail_score
    return result

# %%
print(split_compound_words('communitech', word2index))
print(split_compound_words('biceppower', word2index))
print(split_compound_words('appleworks', word2index))
print(split_compound_words('tmobile', word2index))
print(split_compound_words('northstar', word2index))
print(split_compound_words('griscware', word2index))
print(split_compound_words('windmobile', word2index))
print(split_compound_words('dreamworks', word2index))
print(split_compound_words('quackdoctor', word2index))
print(split_compound_words('fontof', word2index))
# Out:
# ['communi', 'tech']
# ['bicep', 'power']
# ['apple', 'works']
# ['t', 'mobile']
# ['north', 'star']
# ['grisc', 'ware']
# ['wind', 'mobile']
# ['dream', 'works']
# ['quack', 'doctor']
# ['font', 'of']

# %%
words_below_rank(15000)('dreamworks')
# Out:
# 0

# %%
def words_below_rank(rank):
    def count_words_below_rank(d):
        return sum(1 for r in custom_tokenize2(d) if r > 0 and r < rank)
    return count_words_below_rank

# %%
vocab_size, embedding_dim = embedding_matrix.shape
maxlen = 10
print(custom_tokenize2('Rhinoshield'))
print(custom_tokenize2('21039'))
print(custom_tokenize2('what is this, an apple ltd?'))
vocab_size, embedding_dim
# Out:
# [21921, 5728]
# [0]
# [102, 14, 37, 29, 3292, 8196]
# (400001, 200)

# %%
encoded_company_names = [custom_tokenize2(d) for d in rwdf.CompanyName]
encoded_company_names = [d for d in encoded_company_names]
encoded_company_names = pad_sequences(encoded_company_names, maxlen=maxlen, padding='post')

# %%
# Sanity check
len(encoded_company_names), len(industry_labels)
# Out:
# (937376, 937376)

# %% [markdown]
# ### Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    encoded_company_names, industry_labels, test_size=0.15, random_state=42)
y_train.shape
# Out:
# (796769, 300)

# %% [markdown]
# ### Model

# %%
weight_decay = 1e-4
num_filters = 128
n2 = 256
n3 = 128
pool_size = 2
window_size = 3
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=maxlen,
                            weights=[embedding_matrix], trainable=False)
top3 = lambda x, y: top_k_categorical_accuracy(x, y, k=3)
top3.__name__ = 'top3'

model = Sequential()
model.add(embedding_layer)
model.add(Convolution1D(num_filters, window_size, activation='relu', padding='same'))
#model.add(MaxPooling1D(pool_size))
model.add(Convolution1D(num_filters, window_size, activation='relu', padding='same'))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.5))
#model.add(Dense(n2, activation='relu', kernel_regularizer=l2(weight_decay)))
#model.add(Dropout(0.2))
model.add(Dense(n3, activation='relu', kernel_regularizer=l2(weight_decay)))
# model.add(Dropout(0.2))
model.add(Dense(num_industries, activation='sigmoid'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc', top3])
model.summary()
# Out:
# WARNING:tensorflow:From /Users/zeb.zhao/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 10, 200)           80000200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 128)           76928
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 128)           49280
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               38700
# =================================================================
# Total params: 80,181,620
# Trainable params: 181,420
# Non-trainable params: 80,000,200
# _________________________________________________________________

# %% [markdown]
# ### ROC AUC Metric

# %%
class ROCCallback(Callback):
    def __init__(self,training_data,validation_data):
        self.x, self.y = training_data
        self.x_val, self.y_val = validation_data

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict(self.x)
        roc = roc_auc_score(self.y, y_pred)
        y_pred_val = self.model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %% [markdown]
# ### Hook up Tensorboard

# %% [markdown]
# `tensorboard --logdir='tmp'`

# %%
date_suffix = str(datetime.now()).replace(':', '-').split('.')[0]
temp_folder = 'tmp/GloVe%s-fd%s-industry-resmpl-cnn3x%s-%s-gpool-compound-%s' % (
    embedding_dim, num_industries, num_filters, n3, date_suffix)
temp_folder
# Out:
# 'tmp/GloVe200-fd300-industry-resmpl-cnn3x128-128-gpool-compound-2018-03-29 10-33-47'

# %% [markdown]
# ### Train Model

# %%
callbacks = [TensorBoard(log_dir=temp_folder)]
#callbacks.append(ROCCallback((X_train, y_train), (X_test, y_test)))
model.fit(
    X_train, y_train, epochs=18, batch_size=64,
    validation_data=(X_test, y_test),
    callbacks=callbacks)
# Out:
# Train on 796769 samples, validate on 140607 samples
# Epoch 1/18
# 796769/796769 [==============================] - 133s 166us/step - loss: 4.1078 - acc: 0.1610 - top3: 0.2979 - val_loss: 3.7910 - val_acc: 0.2089 - val_top3: 0.3670
# Epoch 2/18
# 796769/796769 [==============================] - 128s 161us/step - loss: 3.8668 - acc: 0.1986 - top3: 0.3499 - val_loss: 3.7396 - val_acc: 0.2199 - val_top3: 0.3787
# Epoch 3/18
# 796769/796769 [==============================] - 128s 161us/step - loss: 3.8191 - acc: 0.2067 - top3: 0.3594 - val_loss: 3.7279 - val_acc: 0.2230 - val_top3: 0.3810
# Epoch 4/18
# 796769/796769 [==============================] - 133s 167us/step - loss: 3.7960 - acc: 0.2103 - top3: 0.3642 - val_loss: 3.7194 - val_acc: 0.2223 - val_top3: 0.3820
# Epoch 5/18
# 796769/796769 [==============================] - 127s 159us/step - loss: 3.7791 - acc: 0.2121 - top3: 0.3671 - val_loss: 3.7102 - val_acc: 0.2258 - val_top3: 0.3844
# Epoch 6/18
# 796769/796769 [==============================] - 124s 155us/step - loss: 3.7690 - acc: 0.2140 - top3: 0.3691 - val_loss: 3.7141 - val_acc: 0.2257 - val_top3: 0.3848
# Epoch 7/18
# 234432/796769 [=======>......................] - ETA: 1:31 - loss: 3.7448 - acc: 0.2162 - top3: 0.3724
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-b695ee65158d> in <module>()
#       4     X_train, y_train, epochs=18, batch_size=64,
#       5     validation_data=(X_test, y_test),
# ----> 6     callbacks=callbacks)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing/Validation

# %%
loss, accuracy, top3 = model.evaluate(X_test, y_test)
accuracy
# Out:
# 140607/140607 [==============================] - 10s 71us/step
# 0.22646809902587908

# %%
y_labels = np.argmax(y_test, axis=1)
y_pred = model.predict_classes(X_test)
y_labels.shape, y_pred.shape
y_scores = model.predict(X_test)
cm = confusion_matrix(y_pred, y_labels)

# %%
print('Verifying accuracy', (y_labels==y_pred).sum()/len(y_pred))
# Out:
# Verifying accuracy 0.226468099028

# %%
def plot_confusion_matrix(cm, encoder):
    pylab.figure(figsize=(18,18))
    cm = cm/cm.sum(axis=0)
    dim, _ =cm.shape
    pylab.matshow(cm, fignum=False, cmap='Blues', vmin=0, vmax=0.5)
    ax = pylab.gca()
    ax.set_xticks(range(dim))
    ax.set_xticklabels(encoder.inverse_transform(pd.Series(range(dim))), rotation='vertical')
    ax.set_yticks(range(dim))
    ax.set_yticklabels(encoder.inverse_transform(pd.Series(range(dim))))
    pylab.colorbar()
    pylab.grid(False)
    pylab.xlabel('Predicted')
    pylab.ylabel('Actual')
    pylab.show()

# %%
plot_confusion_matrix(cm, industry_encoder)

# %%
acc_per_class(cm, industry_encoder)
# Out:
#            acc  total  fcls
# cls
# 980   0.760684    936   683
# 851   0.610419    883   852
# 110   0.608527    774   561
# 511   0.593516    401   791
# 652   0.571429    357   651
# 9602  0.556541    902   561
# 791   0.548425    857   561
# 9603  0.538874    373   011
# 351   0.534753    892   432
# 031   0.531250    384   561
# 591   0.531148    915   731
# 813   0.525140    895   024
# 107   0.515528    483   561
# 750   0.510730    699   862
# 9601  0.505543    451   812
# 692   0.502709    923  6202
# 502   0.496021    377   532
# 231   0.495868    121   222
# 381   0.492284    648   749
# 812   0.488865    943   811
# 881   0.472316    885   521
# 181   0.471316    889   731
# 494   0.469318    880   532
# 561   0.457684    898   108
# 801   0.455882    884   802
# 592   0.445946    888   591
# 691   0.444706    850   692
# 521   0.438265    899   561
# 563   0.435698    902   561
# 015   0.431129    726   011
# 432   0.426174    894   412
# 551   0.422991    896   563
# 451   0.421739    920   452
# 743   0.413625    411   521
# 852   0.411494    870   856
# 237   0.409091     88  9603
# 601   0.408922    269   591
# 452   0.403341    838   451
# 931   0.394168    926  9604
# 6420  0.378705    911   643
# 081   0.378378    111   237
# 024   0.376866    268   813
# 493   0.373747    998   791
# 771   0.373614    902   451
# 862   0.372421    921   861
# 742   0.371681    904   591
# 454   0.371501    393   451
# 802   0.361460    877   801
# 310   0.361015    867   741
# 910   0.358730    630   949
# ...        ...    ...   ...
# 062   0.000000    158   091
# 071   0.000000     17   072
# 103   0.000000    190   108
# 104   0.000000     31   108
# 106   0.000000     45   108
# 120   0.000000     30   108
# 131   0.000000     48  4641
# 132   0.000000     47   139
# 133   0.000000    158   181
# 142   0.000000      4   521
# 143   0.000000     39   139
# 254   0.000000     13   802
# 262   0.000000    135  6201
# 641   0.000000    356  6202
# 303   0.000000    105   511
# 323   0.000000    171   931
# 3291  0.000000      8   162
# 390   0.000000    419   381
# 4611  0.000000    131   016
# 4612  0.000000    215   467
# 012   0.000000    179   015
# 4617  0.000000    389   469
# 4643  0.000000    223   469
# 4644  0.000000     66   469
# 4648  0.000000    233   321
# 492   0.000000     70   494
# 495   0.000000     18   091
# 504   0.000000     21   502
# 612   0.000000    604   619
# 6209  0.000000    881  6201
# 304   0.000000      4   256
# 302   0.000000     66   256
# 263   0.000000     95   619
# 293   0.000000    296   452
# 266   0.000000     17   521
# 267   0.000000     56   265
# 268   0.000000      7   181
# 272   0.000000     16   351
# 273   0.000000     82   351
# 275   0.000000     72  6201
# 283   0.000000     54   256
# 284   0.000000    126   259
# 2891  0.000000      4   463
# 2892  0.000000     27   091
# 2893  0.000000     47   466
# 2894  0.000000     21   011
# 2895  0.000000      8   181
# 2896  0.000000     31   259
# 291   0.000000    154   451
# 990   0.000000    220   949
#
# [300 rows x 3 columns]

# %%
def acc_per_class(cm, encoder):
    cm_scaled = cm/cm.sum(axis=0)
    cm_offdiag_mask = np.ones(cm.shape)
    np.fill_diagonal(cm_offdiag_mask, 0)
    acc = pd.Series(np.diag(cm_scaled))
    acc = acc.reset_index()
    acc['acc'] = acc[0]
    acc['cls'] = encoder.inverse_transform(acc.index)
    acc['total'] = cm.sum(axis=0)
    acc['fcls'] = encoder.inverse_transform(np.argmax(cm*cm_offdiag_mask, axis=0))
    return acc[['cls', 'acc', 'total', 'fcls']].set_index('cls').sort_values('acc', ascending=False)

# %%
def bubble_plot(cm, encoder, xlim=None, ylim=None):
    df = acc_per_class(cm, encoder).reset_index()
    df['ind'] = encoder.transform(df['cls'])
    df['find'] = encoder.transform(df['fcls'])
    ax = pylab.gca()
    df.plot.scatter(ax=ax, x='find', y='ind', s=df['total']*0.5, c='acc',
                         figsize=(18, 15), cmap=cmap.get_cmap('Spectral'))
    dim = len(df)
    cls = encoder.inverse_transform(pd.Series(range(dim)))
    ax.set_xticks(range(dim))
    ax.set_xticklabels(cls, rotation='vertical')
    ax.set_yticks(range(dim))
    ax.set_yticklabels(cls)
    if xlim is not None:
        ax.set_xlim(xlim)
    if ylim is not None:
        ax.set_ylim(ylim)
    pylab.xlabel('Predicted Class')
    pylab.ylabel('Actual Class')
    pylab.gcf().tight_layout()
    for i, txt in enumerate(df['cls']):
        ax.annotate('%s, %s' % (df.fcls.iat[i], df.cls.iat[i]), (df.find.iat[i], df.ind.iat[i]))

# %%
bubble_plot(cm, industry_encoder, [1, 150], [1, 150])

# %%
bubble_plot(cm, industry_encoder, [150, 300], [150, 300])

# %% [markdown]
# ### ROC Evaluation

# %%
def plot_roc(y_test, y_score, encoder):
    # Compute ROC curve and area for each class
    print('ROC AUC Score: %s' % roc_auc_score(y_test, y_score))
    lw = 2
    n_classes = y_test.shape[1]
    fpr, tpr, roc_auc = {}, {}, {}
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    fig, ax = pylab.subplots()
    fig.set_figwidth(12)
    fig.set_figheight(8)
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'crimson', 'navy',
                    'darksalmon', 'cadetblue', 'deeppink', 'darkolivegreen', 'fuchsia'])
    sorted_classes = sorted(range(n_classes), key=lambda i: roc_auc[i])
    for i, color in zip(sorted_classes, colors):
        ax.plot(fpr[i], tpr[i], color=color, lw=lw,
                label='ROC curve of class {0} (area = {1:0.2f})'
                ''.format(encoder.inverse_transform(i), roc_auc[i]))
    ax.plot([0, 1], [0, 1], 'k--', lw=lw)
    pylab.xlim([0.0, 1.0])
    pylab.ylim([0.0, 1.05])
    pylab.xlabel('False Positive Rate')
    pylab.ylabel('True Positive Rate')
    ax.legend(loc="lower left", bbox_to_anchor=(0.0, 1.01), ncol=4, frameon=False)
    pylab.show()

# %%
plot_roc(y_test, y_scores, industry_encoder)

# %% [markdown]
# ### Test with Original Sampling

# %%
industry_encoder = LabelEncoder()
industry_encoder.fit(wdf['Industry'])
encoded_industry = industry_encoder.transform(wdf['Industry'])
industry_labels = np_utils.to_categorical(encoded_industry)
industry_labels.shape

# %%
encoded_company_names = [custom_tokenize(d) for d in wdf.CompanyName]
encoded_company_names = [d for d in encoded_company_names]
encoded_company_names = pad_sequences(encoded_company_names, maxlen=maxlen, padding='post')

# %%
# Sanity check
len(encoded_company_names), len(industry_labels)

# %%
y_pred_score = model.predict(encoded_company_names)

# %%
industry_labels.shape, y_pred_score.shape

# %%
# Top K accuracy
print('Top1: %s' % top_k_categorical_accuracy(industry_labels, y_pred_score, k=1))
print('Top3: %s' % top_k_categorical_accuracy(industry_labels, y_pred_score, k=3))
print('Top5: %s' % top_k_categorical_accuracy(industry_labels, y_pred_score, k=5))

# %%
loss, accuracy = model.evaluate(encoded_company_names, industry_labels)
accuracy

# %%
y_labels = np.argmax(y_test, axis=1)
y_pred = model.predict_classes(encoded_company_names)
y_labels.shape, y_pred.shape
cm = confusion_matrix(y_pred, y_labels)

# %%
plot_confusion_matrix(cm, [])

# %%
acc_per_class(cm, industry_encoder)

# %% [markdown]
# ### Save/Load Model

# %%
model_output = 'models/%s-acc%0.4f.h5' % ('Trial12-GloVe200-Stacked-4m-CNN-Pooled-No-NEC-Compound', accuracy)
model.save(model_output)
model_output

# %%
model = load_model('models/Trial10-GloVe100-Stacked-4m-CNN-Pooled-No-NEC-acc0.3378.h5')

# %% [markdown]
# ### Play with Model

# %%
SIC_df = pd.read_csv('SIC07_CH_condensed_list_en.csv', dtype={'SIC Code': 'object'})

# %%
def pretext(precode):
    return '\n'.join('\t\t%s\t%s' % (value['SIC Code'], value.Description[:90]) 
                     for i, value in SIC_df[SIC_df['SIC Code'].str.startswith(precode)].iterrows())

# %%
while True:
    name = input()
    if not name:
        break
    name = re.sub(r"[\-,'\"]", " ", name)
    encoded = custom_tokenize2(name)
    if sum(encoded) == 0:
        print('\tWords in the input are not recognized.')
        continue
    encoded_company_name = pad_sequences([encoded], maxlen=maxlen, padding='post')
    pred = model.predict(encoded_company_name).flatten()
    probas = sorted(enumerate(pred), key=lambda x: x[1], reverse=True)[:3]
    total = sum(pred)
    if max(pred)/total < 0.1:
        print('\tNo classification exceeds 10% likelihood.')
        continue
    for i, p in probas:
        code = industry_encoder.inverse_transform(i)
        print('\t%0.2f%%' % (p/total*100))
        print(pretext(code))
# Out:
# accrued holdings limited
# 	16.44%
# 		64201	Activities of agricultural holding companies
# 		64202	Activities of production holding companies
# 		64203	Activities of construction holding companies
# 		64204	Activities of distribution holding companies
# 		64205	Activities of financial services holding companies
# 		64209	Activities of other holding companies n.e.c.
# 	14.50%
# 		70100	Activities of head offices
# 	5.04%
# 		64301	Activities of investment trusts
# 		64302	Activities of unit trusts
# 		64303	Activities of venture and development capital companies
# 		64304	Activities of open-ended investment companies
# 		64305	Activities of property unit trusts
# 		64306	Activities of real estate investment trusts
# google
# 	13.36%
# 		62011	Ready-made interactive leisure and entertainment software development
# 		62012	Business and domestic software development
# 	11.52%
# 		63110	Data processing, hosting and related activities
# 		63120	Web portals
# 	10.35%
# 		62090	Other information technology service activities
